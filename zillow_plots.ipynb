# %% [markdown]
# # Zillow Housing Data
# - June 2022

# %%
import pandas as pd
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go

# %%
house = pd.read_csv('Metro_invt_fs_uc_sfrcondo_sm_month.csv')
rent = pd.read_csv('Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
inv = pd.read_csv('Metro_ZORI_AllHomesPlusMultifamily_Smoothed.csv')

# %%
house.head(21)
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 0     102001         0                       United States    Country
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# 5     394974         5                    Philadelphia, PA        Msa
# 6     394692         6                         Houston, TX        Msa
# 7     395209         7                      Washington, DC        Msa
# 8     394856         8           Miami-Fort Lauderdale, FL        Msa
# 9     394347         9                         Atlanta, GA        Msa
# 10    394404        10                          Boston, MA        Msa
# 11    395057        11                   San Francisco, CA        Msa
# ...

# %%
#house.info()

# %%
house2 = house.drop(columns=['RegionID', 'SizeRank', 'RegionType', 'StateName'])
house2 = house2.set_index('RegionName')

# %%
house2.head()
# Out:
#                                     2018-01-31  2018-02-28  2018-03-31  \
# RegionName
# United States                        1425450.0   1382830.0   1439851.0
# New York, NY                           68840.0     68388.0     72876.0
# Los Angeles-Long Beach-Anaheim, CA     20023.0     19856.0     21809.0
# Chicago, IL                            42641.0     40958.0     44548.0
# Dallas-Fort Worth, TX                  24274.0     23197.0     24340.0
#
#                                     2018-04-30  2018-05-31  2018-06-30  \
# RegionName
# United States                        1526848.0   1628515.0   1702187.0
# New York, NY                           79788.0     85802.0     90328.0
# Los Angeles-Long Beach-Anaheim, CA     23726.0     25688.0     27275.0
# Chicago, IL                            49069.0     53582.0     55954.0
# Dallas-Fort Worth, TX                  26747.0     29540.0     31955.0
#
#                                     2018-07-31  2018-08-31  2018-09-30  \
# ...

# %%
houseT = house2.T

# %%
houseT.head()
# Out:
# RegionName  United States  New York, NY  Los Angeles-Long Beach-Anaheim, CA  \
# 2018-01-31      1425450.0       68840.0                             20023.0
# 2018-02-28      1382830.0       68388.0                             19856.0
# 2018-03-31      1439851.0       72876.0                             21809.0
# 2018-04-30      1526848.0       79788.0                             23726.0
# 2018-05-31      1628515.0       85802.0                             25688.0
#
# RegionName  Chicago, IL  Dallas-Fort Worth, TX  Philadelphia, PA  Houston, TX  \
# 2018-01-31      42641.0                24274.0           26461.0      33616.0
# 2018-02-28      40958.0                23197.0           25023.0      32758.0
# 2018-03-31      44548.0                24340.0           26052.0      34408.0
# 2018-04-30      49069.0                26747.0           28326.0      36508.0
# 2018-05-31      53582.0                29540.0           30621.0      39383.0
#
# ...

# %%
fig = px.line(houseT, x=houseT.index, y=houseT['Los Angeles-Long Beach-Anaheim, CA'])
fig = px.line(houseT, x=houseT.index, y=houseT['San Diego, CA'])
#fig = px.line(houseT, x=houseT.index, y=houseT['Dallas-Fort Worth, TX'])
#fig = px.line(houseT, x=houseT.index, y=houseT['Phoenix, AZ'])
#fig = px.line(houseT, x=houseT.index, y=houseT['Los Angeles-Long Beach-Anaheim, CA'])


fig.show()
# Out:
# <div>                            <div id="f40df4ee-201d-4844-97c6-2bac6e314d6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f40df4ee-201d-4844-97c6-2bac6e314d6f")) {                    Plotly.newPlot(                        "f40df4ee-201d-4844-97c6-2bac6e314d6f",                        [{"hovertemplate":"index=%{x}<br>San Diego, CA=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2018-01-31","2018-02-28","2018-03-31","2018-04-30","2018-05-31","2018-06-30","2018-07-31","2018-08-31","2018-09-30","2018-10-31","2018-11-30","2018-12-31","2019-01-31","2019-02-28","2019-03-31","2019-04-30","2019-05-31","2019-06-30","2019-07-31
# ...

# %%
houseT.index
# Out:
# Index(['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
#        '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31',
#        '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31',
#        '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#        '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31',
#        '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30',
#        '2020-07-31', '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30',
#        '2020-12-31', '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#        '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31', '2021-09-30',
#        '2021-10-31', '2021-11-30', '2021-12-31', '2022-01-31', '2022-02-28',
#        '2022-03-31', '2022-04-30'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

house2.index
# Out:
# Index(['United States', 'New York, NY', 'Los Angeles-Long Beach-Anaheim, CA',
#        'Chicago, IL', 'Dallas-Fort Worth, TX', 'Philadelphia, PA',
#        'Houston, TX', 'Washington, DC', 'Miami-Fort Lauderdale, FL',
#        'Atlanta, GA',
#        ...
#        'Winnemucca, NV', 'Sweetwater, TX', 'Andrews, TX', 'Zapata, TX',
#        'Vermillion, SD', 'Lamesa, TX', 'Craig, CO', 'Pecos, TX', 'Vernon, TX',
#        'Ketchikan, AK'],
#       dtype='object', name='RegionName', length=917)

# %%
pd.DataFrame(house2.index)
# Out:
#                                  RegionName
# 0                             United States
# 1                              New York, NY
# 2        Los Angeles-Long Beach-Anaheim, CA
# 3                               Chicago, IL
# 4                     Dallas-Fort Worth, TX
# 5                          Philadelphia, PA
# 6                               Houston, TX
# 7                            Washington, DC
# 8                 Miami-Fort Lauderdale, FL
# 9                               Atlanta, GA
# 10                               Boston, MA
# 11                        San Francisco, CA
# 12                              Detroit, MI
# 13                            Riverside, CA
# 14                              Phoenix, AZ
# 15                              Seattle, WA
# 16                  Minneapolis-St Paul, MN
# 17                            San Diego, CA
# 18                            St. Louis, MO
# 19                                Tampa, FL
# ...
